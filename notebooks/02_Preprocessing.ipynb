# %% [markdown]
# # 02 - Preprocessing
# Execute preprocessing steps and save processed data.

# %%
from pathlib import Path
from src.data_loader import load_or_download
from src.preprocessor import preprocess_data

base_dir = Path('..').resolve()
df = load_or_download(base_dir / 'data')
preprocess_data(df, output_dir=base_dir / 'data' / 'processed', target_col='defects')
